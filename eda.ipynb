# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_cleaned.csv')
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          LOW FAT         0.016047
# 1           DRC01         5.92          REGULAR         0.019278
# 2           FDN15        17.50          LOW FAT         0.016760
# 3           FDX07        19.20          REGULAR         0.000000
# 4           NCD19         8.93          LOW FAT         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type2
# 2  Supermarket Type1
# 3      Grocery Store
# 4  Supermarket Type1

# %%
data.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year
# count  14204.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.234226         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        9.300000         0.027036     94.012000                1987.000000
# 50%       12.792854         0.054021    142.247000                1999.000000
# 75%       16.000000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data_cat = data[['Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size', 'Outlet_Location_Type',
       'Outlet_Type']]
list(enumerate(data_cat))
# Out:
# [(0, 'Item_Fat_Content'),
#  (1, 'Item_Type'),
#  (2, 'Outlet_Identifier'),
#  (3, 'Outlet_Size'),
#  (4, 'Outlet_Location_Type'),
#  (5, 'Outlet_Type')]

# %%
for i in data_cat:
    plt.figure(figsize = (5,5))
    cat_num = data[i].value_counts()
    sns.barplot(x = cat_num.index, y = cat_num)
    plt.xticks(fontsize=8,rotation = 90)
    plt.show()

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
sns.heatmap(data[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']].corr())
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          LOW FAT         0.016047
# 1           DRC01         5.92          REGULAR         0.019278
# 2           FDN15        17.50          LOW FAT         0.016760
# 3           FDX07        19.20          REGULAR         0.000000
# 4           NCD19         8.93          LOW FAT         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type2
# 2  Supermarket Type1
# 3      Grocery Store
# 4  Supermarket Type1

# %%
plt.figure(figsize = (20,5))
sns.barplot(x ='Item_Type' , y = 'Item_Weight',data =data)
plt.xticks(rotation = 90)
plt.show()

# %%
data.nunique()
# Out:
# Item_Identifier               1559
# Item_Weight                    416
# Item_Fat_Content                 2
# Item_Visibility              13006
# Item_Type                       16
# Item_MRP                      8052
# Outlet_Identifier               10
# Outlet_Establishment_Year        9
# Outlet_Size                      3
# Outlet_Location_Type             3
# Outlet_Type                      4
# dtype: int64

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          LOW FAT         0.016047
# 1           DRC01         5.92          REGULAR         0.019278
# 2           FDN15        17.50          LOW FAT         0.016760
# 3           FDX07        19.20          REGULAR         0.000000
# 4           NCD19         8.93          LOW FAT         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type2
# 2  Supermarket Type1
# 3      Grocery Store
# 4  Supermarket Type1

# %%
data[data['Item_Weight'] == 17.50]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2               FDN15         17.5          LOW FAT         0.016760
# 34              DRH01         17.5          LOW FAT         0.097904
# 249             FDF05         17.5          LOW FAT         0.027023
# 427             FDN32         17.5          LOW FAT         0.015624
# 759             FDN15         17.5          LOW FAT         0.028009
# 1045            FDB40         17.5          REGULAR         0.007555
# 1049            FDF04         17.5          LOW FAT         0.013634
# 1098            FDF05         17.5          LOW FAT         0.026925
# 1326            FDF04         17.5          LOW FAT         0.000000
# 1813            FDF05         17.5          LOW FAT         0.026871
# 2192            FDY45         17.5          LOW FAT         0.000000
# 2974            FDP57         17.5          LOW FAT         0.052658
# 3429            FDF05         17.5          LOW FAT         0.026913
# 3806            FDB40         17.5          REGULAR         0.007552
# 3893            FDF04         17.5          LOW FAT         0.013658
# 4071            FDY45         17.5          LOW FAT         0.026249
# 4074            FDF05         17.5          LOW FAT         0.026866
# 4077            FDP57         17.5          LOW FAT         0.052741
# 4084            FDY45         17.5          LOW FAT         0.026195
# 4123            FDB40         17.5          REGULAR         0.007538
# 4162            FDP57         17.5          LOW FAT         0.000000
# 4636            FDB40         17.5          REGULAR         0.007571
# 4817            FDN15         17.5          LOW FAT         0.016720
# 4824            FDF04         17.5          LOW FAT         0.013665
# 4860            FDP57         17.5          LOW FAT         0.052550
# 5038            FDN32         17.5          LOW FAT         0.015585
# 5074            FDN15         17.5          LOW FAT         0.016802
# 5469            FDY45         17.5          LOW FAT         0.026290
# 5545            DRH01         17.5          LOW FAT         0.098103
# 5664            FDY45         17.5          LOW FAT         0.026183
# 5968            FDF05         17.5          LOW FAT         0.026849
# 6163            FDN15         17.5          LOW FAT         0.016768
# 6764            FDN32         17.5          LOW FAT         0.015557
# 7203            FDF04         17.5          LOW FAT         0.013693
# 7622            FDB40         17.5          REGULAR         0.012620
# 7723            FDN32         17.5          LOW FAT         0.015592
# 7801            DRH01         17.5          LOW FAT         0.098458
# 7886            FDP57         17.5          LOW FAT         0.052434
# 8087            FDF04         17.5          LOW FAT         0.013637
# 8342            FDF04         17.5          LOW FAT         0.013714
# 8511            FDF05         17.5          LOW FAT         0.026980
# 8753            FDY45         17.5          LOW FAT         0.000000
# 9014            FDY45         17.5          LOW FAT         0.026142
# 9147            DRH01         17.5          LOW FAT         0.098056
# 9682            FDN15         17.5          LOW FAT         0.016731
# 9925            FDP57         17.5          LOW FAT         0.052526
# 10046           DRH01         17.5          LOW FAT         0.097886
# 10109           DRH01         17.5          LOW FAT         0.097823
# 10626           FDN32         17.5          LOW FAT         0.015560
# 10649           FDN32         17.5          LOW FAT         0.015547
# 10950           DRH01         17.5          LOW FAT         0.098303
# 11173           FDN32         17.5          LOW FAT         0.026045
# 12603           FDN15         17.5          LOW FAT         0.016829
# 12623           FDN32         17.5          LOW FAT         0.015648
# 12814           FDY45         17.5          LOW FAT         0.043757
# 12968           FDP57         17.5          LOW FAT         0.052400
# 13358           FDN15         17.5          LOW FAT         0.000000
# 13448           FDB40         17.5          REGULAR         0.007540
# 13584           FDP57         17.5          LOW FAT         0.087781
# 13773           FDB40         17.5          REGULAR         0.007583
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 2                       Meat  141.6180            OUT049
# 34               Soft Drinks  174.8738            OUT046
# 249             Frozen Foods  262.4910            OUT017
# 427    Fruits and Vegetables  182.6266            OUT018
# 759                     Meat  141.7180            OUT010
# 1045                   Dairy  145.9102            OUT045
# 1049            Frozen Foods  256.4304            OUT035
# 1098            Frozen Foods  264.3910            OUT045
# 1326            Frozen Foods  258.3304            OUT013
# 1813            Frozen Foods  264.4910            OUT046
# 2192             Snack Foods  253.0356            OUT035
# 2974             Snack Foods  103.6990            OUT018
# 3429            Frozen Foods  261.2910            OUT049
# 3806                   Dairy  145.8102            OUT049
# 3893            Frozen Foods  256.3304            OUT049
# 4071             Snack Foods  255.1356            OUT018
# 4074            Frozen Foods  261.6910            OUT035
# 4077             Snack Foods  103.7990            OUT017
# 4084             Snack Foods  252.6356            OUT045
# 4123                   Dairy  144.2102            OUT035
# 4162             Snack Foods  102.9990            OUT046
# 4636                   Dairy  144.6102            OUT018
# 4817                    Meat  139.9180            OUT013
# 4824            Frozen Foods  257.7304            OUT045
# 4860             Snack Foods  101.2990            OUT045
# 5038   Fruits and Vegetables  185.1266            OUT049
# 5074                    Meat  138.5180            OUT018
# 5469             Snack Foods  253.7356            OUT017
# 5545             Soft Drinks  172.9738            OUT045
# 5664             Snack Foods  253.6356            OUT049
# 5968            Frozen Foods  264.8910            OUT013
# 6163                    Meat  141.4180            OUT045
# 6764   Fruits and Vegetables  184.7266            OUT035
# 7203            Frozen Foods  259.7304            OUT018
# 7622                   Dairy  144.8102            OUT010
# 7723   Fruits and Vegetables  184.8266            OUT045
# 7801             Soft Drinks  171.7738            OUT017
# 7886             Snack Foods  103.9990            OUT035
# 8087            Frozen Foods  258.5304            OUT046
# 8342            Frozen Foods  259.2304            OUT017
# 8511            Frozen Foods  262.5910            OUT018
# 8753             Snack Foods  255.2356            OUT013
# 9014             Snack Foods  256.3356            OUT046
# 9147             Soft Drinks  175.7738            OUT049
# 9682                    Meat  139.0180            OUT035
# 9925             Snack Foods  104.3990            OUT049
# 10046            Soft Drinks  172.6738            OUT035
# 10109            Soft Drinks  175.4738            OUT013
# 10626  Fruits and Vegetables  185.6266            OUT046
# 10649  Fruits and Vegetables  183.3266            OUT013
# 10950            Soft Drinks  173.4738            OUT018
# 11173  Fruits and Vegetables  185.2266            OUT010
# 12603                   Meat  138.4180            OUT017
# 12623  Fruits and Vegetables  182.5266            OUT017
# 12814            Snack Foods  252.9356            OUT010
# 12968            Snack Foods  105.0990            OUT013
# 13358                   Meat  140.4180            OUT046
# 13448                  Dairy  145.7102            OUT046
# 13584            Snack Foods  105.0990            OUT010
# 13773                  Dairy  145.5102            OUT017
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2                           1999      Medium               Tier 1
# 34                          1997       Small               Tier 1
# 249                         2007      Medium               Tier 2
# 427                         2009      Medium               Tier 3
# 759                         1998      Medium               Tier 3
# 1045                        2002      Medium               Tier 2
# 1049                        2004       Small               Tier 2
# 1098                        2002      Medium               Tier 2
# 1326                        1987        High               Tier 3
# 1813                        1997       Small               Tier 1
# 2192                        2004       Small               Tier 2
# 2974                        2009      Medium               Tier 3
# 3429                        1999      Medium               Tier 1
# 3806                        1999      Medium               Tier 1
# 3893                        1999      Medium               Tier 1
# 4071                        2009      Medium               Tier 3
# 4074                        2004       Small               Tier 2
# 4077                        2007      Medium               Tier 2
# 4084                        2002      Medium               Tier 2
# 4123                        2004       Small               Tier 2
# 4162                        1997       Small               Tier 1
# 4636                        2009      Medium               Tier 3
# 4817                        1987        High               Tier 3
# 4824                        2002      Medium               Tier 2
# 4860                        2002      Medium               Tier 2
# 5038                        1999      Medium               Tier 1
# 5074                        2009      Medium               Tier 3
# 5469                        2007      Medium               Tier 2
# 5545                        2002      Medium               Tier 2
# 5664                        1999      Medium               Tier 1
# 5968                        1987        High               Tier 3
# 6163                        2002      Medium               Tier 2
# 6764                        2004       Small               Tier 2
# 7203                        2009      Medium               Tier 3
# 7622                        1998      Medium               Tier 3
# 7723                        2002      Medium               Tier 2
# 7801                        2007      Medium               Tier 2
# 7886                        2004       Small               Tier 2
# 8087                        1997       Small               Tier 1
# 8342                        2007      Medium               Tier 2
# 8511                        2009      Medium               Tier 3
# 8753                        1987        High               Tier 3
# 9014                        1997       Small               Tier 1
# 9147                        1999      Medium               Tier 1
# 9682                        2004       Small               Tier 2
# 9925                        1999      Medium               Tier 1
# 10046                       2004       Small               Tier 2
# 10109                       1987        High               Tier 3
# 10626                       1997       Small               Tier 1
# 10649                       1987        High               Tier 3
# 10950                       2009      Medium               Tier 3
# 11173                       1998      Medium               Tier 3
# 12603                       2007      Medium               Tier 2
# 12623                       2007      Medium               Tier 2
# 12814                       1998      Medium               Tier 3
# 12968                       1987        High               Tier 3
# 13358                       1997       Small               Tier 1
# 13448                       1997       Small               Tier 1
# 13584                       1998      Medium               Tier 3
# 13773                       2007      Medium               Tier 2
#
#              Outlet_Type
# 2      Supermarket Type1
# 34     Supermarket Type1
# 249    Supermarket Type1
# 427    Supermarket Type2
# 759        Grocery Store
# 1045   Supermarket Type1
# 1049   Supermarket Type1
# 1098   Supermarket Type1
# 1326   Supermarket Type1
# 1813   Supermarket Type1
# 2192   Supermarket Type1
# 2974   Supermarket Type2
# 3429   Supermarket Type1
# 3806   Supermarket Type1
# 3893   Supermarket Type1
# 4071   Supermarket Type2
# 4074   Supermarket Type1
# 4077   Supermarket Type1
# 4084   Supermarket Type1
# 4123   Supermarket Type1
# 4162   Supermarket Type1
# 4636   Supermarket Type2
# 4817   Supermarket Type1
# 4824   Supermarket Type1
# 4860   Supermarket Type1
# 5038   Supermarket Type1
# 5074   Supermarket Type2
# 5469   Supermarket Type1
# 5545   Supermarket Type1
# 5664   Supermarket Type1
# 5968   Supermarket Type1
# 6163   Supermarket Type1
# 6764   Supermarket Type1
# 7203   Supermarket Type2
# 7622       Grocery Store
# 7723   Supermarket Type1
# 7801   Supermarket Type1
# 7886   Supermarket Type1
# 8087   Supermarket Type1
# 8342   Supermarket Type1
# 8511   Supermarket Type2
# 8753   Supermarket Type1
# 9014   Supermarket Type1
# 9147   Supermarket Type1
# 9682   Supermarket Type1
# 9925   Supermarket Type1
# 10046  Supermarket Type1
# 10109  Supermarket Type1
# 10626  Supermarket Type1
# 10649  Supermarket Type1
# 10950  Supermarket Type2
# 11173      Grocery Store
# 12603  Supermarket Type1
# 12623  Supermarket Type1
# 12814      Grocery Store
# 12968  Supermarket Type1
# 13358  Supermarket Type1
# 13448  Supermarket Type1
# 13584      Grocery Store
# 13773  Supermarket Type1

# %%
plt.figure(figsize=(30,6))
sns.countplot(x='Item_Type', data=data)
plt.show()

# %%
import pandas as pd
data = pd.read_csv('data_cleaned.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          LOW FAT         0.016047
# 1           DRC01         5.92          REGULAR         0.019278
# 2           FDN15        17.50          LOW FAT         0.016760
# 3           FDX07        19.20          REGULAR         0.000000
# 4           NCD19         8.93       Non-Edible         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type    New_Item_Type  Outlet_Years
# 0  Supermarket Type1             Food            14
# 1  Supermarket Type2           Drinks             4
# 2  Supermarket Type1             Food            14
# 3      Grocery Store             Food            15
# 4  Supermarket Type1  Non-Consumables            26
